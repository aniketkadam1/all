# %%
import pandas as pd

# %%
pd.read_csv('D:/project/datasets-master/datasets-master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train=pd.read_csv('D:/project/datasets-master/datasets-master/titanic.csv')
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_train.dtypes =='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
titanic_train.dtypes[titanic_train.dtypes =='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train1=titanic_train[titanic_train.dtypes[titanic_train.dtypes =='object'].index]

# %%
titanic_train1.describe()
# Out:
#                       Name   Sex    Ticket        Cabin Embarked
# count                  891   891       891          204      889
# unique                 891     2       681          147        3
# top     Svensson, Mr. Olof  male  CA. 2343  C23 C25 C27        S
# freq                     1   577         7            4      644

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
type(titanic_train['Pclass'])
# Out:
# pandas.core.series.Series

# %%
titanic_train['Pclass'][0:5]
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass, dtype: int64

# %%
titanic_train['Pclass'][5:0:-1]
# Out:
# 5    3
# 4    3
# 3    1
# 2    3
# 1    1
# Name: Pclass, dtype: int64

# %%
titanic_train[['Survived','Embarked']]
# Out:
#      Survived Embarked
# 0           0        S
# 1           1        C
# 2           1        S
# 3           1        S
# 4           0        S
# ..        ...      ...
# 886         0        S
# 887         1        S
# 888         0        S
# 889         1        C
# 890         0        Q
#
# [891 rows x 2 columns]

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train["aniket"]="kadam"

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# aniket          object
# dtype: object

# %%
pd.Categorical(titanic_train['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(titanic_train['PassengerId'])
# Out:
# [1, 2, 3, 4, 5, ..., 887, 888, 889, 890, 891]
# Length: 891
# Categories (891, int64): [1, 2, 3, 4, ..., 888, 889, 890, 891]

# %%
pd.Categorical(titanic_train['aniket'])
# Out:
# ['kadam', 'kadam', 'kadam', 'kadam', 'kadam', ..., 'kadam', 'kadam', 'kadam', 'kadam', 'kadam']
# Length: 891
# Categories (1, object): ['kadam']

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# aniket          object
# dtype: object

# %%
type(titanic_train['Age'].isnull() ==True)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
np.where(titanic_train['Age'].isnull() ==True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic_train['Age'][5]
# Out:
# nan

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked aniket
# 0      0         A/5 21171   7.2500   NaN        S  kadam
# 1      0          PC 17599  71.2833   C85        C  kadam
# 2      0  STON/O2. 3101282   7.9250   NaN        S  kadam
# 3      0            113803  53.1000  C123        S  kadam
# ...

# %%
np.where(titanic_train["Fare"]==max(titanic_train['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
np.where(titanic_train['Sex']=='male')
# Out:
# (array([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,  21,  23,  26,
#          27,  29,  30,  33,  34,  35,  36,  37,  42,  45,  46,  48,  50,
#          51,  54,  55,  57,  59,  60,  62,  63,  64,  65,  67,  69,  70,
#          72,  73,  74,  75,  76,  77,  78,  80,  81,  83,  86,  87,  89,
#          90,  91,  92,  93,  94,  95,  96,  97,  99, 101, 102, 103, 104,
#         105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124,
#         125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144,
#         145, 146, 148, 149, 150, 152, 153, 154, 155, 157, 158, 159, 160,
#         162, 163, 164, 165, 168, 169, 170, 171, 173, 174, 175, 176, 178,
#         179, 181, 182, 183, 185, 187, 188, 189, 191, 193, 196, 197, 200,
#         201, 202, 203, 204, 206, 207, 209, 210, 212, 213, 214, 217, 219,
#         220, 221, 222, 223, 224, 225, 226, 227, 228, 231, 232, 234, 236,
#         238, 239, 242, 243, 244, 245, 248, 249, 250, 252, 253, 260, 261,
# ...

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'aniket'],
#       dtype='object')

# %%
titanic_train.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# aniket                                                     kadam
# Name: 1, dtype: object

# %%
titanic_train.iloc[[1,2]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked aniket
# 1      0          PC 17599  71.2833   C85        C  kadam
# 2      0  STON/O2. 3101282   7.9250   NaN        S  kadam

# %%
titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     aniket
# 258  kadam
# 679  kadam
# 737  kadam

# %%
titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
np.where(titanic_train['Survived']==1)
# Out:
# (array([  1,   2,   3,   8,   9,  10,  11,  15,  17,  19,  21,  22,  23,
#          25,  28,  31,  32,  36,  39,  43,  44,  47,  52,  53,  55,  56,
#          58,  61,  65,  66,  68,  74,  78,  79,  81,  82,  84,  85,  88,
#          97,  98, 106, 107, 109, 123, 125, 127, 128, 133, 136, 141, 142,
#         146, 151, 156, 161, 165, 166, 172, 183, 184, 186, 187, 190, 192,
#         193, 194, 195, 198, 204, 207, 208, 209, 211, 215, 216, 218, 220,
#         224, 226, 230, 233, 237, 241, 247, 248, 255, 256, 257, 258, 259,
#         261, 267, 268, 269, 271, 272, 274, 275, 279, 283, 286, 288, 289,
#         290, 291, 298, 299, 300, 301, 303, 305, 306, 307, 309, 310, 311,
#         315, 316, 318, 319, 322, 323, 325, 327, 328, 329, 330, 334, 337,
#         338, 340, 341, 345, 346, 347, 348, 356, 358, 359, 366, 367, 368,
#         369, 370, 375, 376, 380, 381, 383, 387, 389, 390, 391, 393, 394,
#         399, 400, 407, 412, 414, 416, 417, 426, 427, 429, 430, 431, 432,
# ...

# %%
len((titanic_train.iloc[np.where(titanic_train['Survived']==1)])['Name'])
# Out:
# 342

# %%
lables=['a','b','c']
list_1=[12,2,45]
array=np.array(list_1)
d={'a':34,'b':30,'c':56}

# %%
pd.Series(list_1)
# Out:
# 0    12
# 1     2
# 2    45
# dtype: int64

# %%
s1=pd.Series(list_1,index=["aniket","kadam","asf"])

# %%
s1
# Out:
# aniket    12
# kadam      2
# asf       45
# dtype: int64

# %%
s1[0]
# Out:
# 12

# %%
s1[0:3]
# Out:
# aniket    12
# kadam      2
# asf       45
# dtype: int64

# %%
s1['aniket']
# Out:
# 12

# %%
array
# Out:
# array([12,  2, 45])

# %%
pd.Series(array)
# Out:
# 0    12
# 1     2
# 2    45
# dtype: int32

# %%
d
# Out:
# {'a': 34, 'b': 30, 'c': 56}

# %%
s2=pd.Series(d)

# %%
s2[0]
# Out:
# 34

# %%
s2['a']
# Out:
# 34

# %%
s1=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s2=pd.Series([7,2,3,4,5],index=['a','b','c','c','e'])
s2
# Out:
# a    7
# b    2
# c    3
# c    4
# e    5
# dtype: int64

# %% [markdown]
# ##

# %%
s2['c']
# Out:
# c    3
# c    4
# dtype: int64

# %%
s1+s2
# Out:
# a     8.0
# b     4.0
# c     6.0
# c     7.0
# d     NaN
# e    10.0
# dtype: float64

# %%
s1*s2
# Out:
# a     7.0
# b     4.0
# c     9.0
# c    12.0
# d     NaN
# e    25.0
# dtype: float64

# %%
s3=s1*s2

# %%
s3
# Out:
# a     7.0
# b     4.0
# c     9.0
# c    12.0
# d     NaN
# e    25.0
# dtype: float64

# %%
s3['a']
# Out:
# 7.0

# %%
s3.loc['a']
# Out:
# 7.0

# %%
from numpy.random import randn as rn

# %%
rn(5,5)
# Out:
# array([[ 1.06524325,  0.42383415, -0.46131029,  0.18025326,  0.67223801],
#        [ 0.01362063,  1.54739542, -0.07059189, -1.19404298,  1.83533575],
#        [-0.92394963,  0.18278562, -1.36691518,  1.05776302,  0.86524566],
#        [ 0.35864011, -0.56065265, -0.86656812, -0.22025943,  0.26164287],
#        [-0.69841786, -0.68504957,  0.2191256 , -0.1625013 , -1.4602616 ]])

# %%
pd.DataFrame(rn(5,5))
# Out:
#           0         1         2         3         4
# 0 -0.096312  0.566193 -0.691597  0.750712  0.025490
# 1  0.779451  1.520371 -0.399961 -0.016230 -0.461460
# 2 -0.001500  1.157746  0.551227 -1.303382 -1.985943
# 3  0.717153 -0.330729 -2.187784  0.658047 -1.497776
# 4 -0.245223 -0.253605 -0.881232 -1.328629  1.859897

# %%
df=pd.DataFrame(rn(5,5),index=['a','b','c','d','e'],columns=['w','x','y','z','v'])

# %%
df
# Out:
#           w         x         y         z         v
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619

# %%
df.iloc[[0,3]]
# Out:
#           w         x         y         z         v
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798

# %%
df.iloc[[3]]
# Out:
#          w         x         y         z         v
# d -1.39137 -1.669714  0.939009 -0.052653 -0.479798

# %%
df.iloc[[3,0,-1]]
# Out:
#           w         x         y         z         v
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619

# %%
df
# Out:
#           w         x         y         z         v
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619

# %%
df.loc[['d']]
# Out:
#          w         x         y         z         v
# d -1.39137 -1.669714  0.939009 -0.052653 -0.479798

# %%
df.loc[['a','b','d']]
# Out:
#           w         x         y         z         v
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798

# %%
df
# Out:
#           w         x         y         z         v
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619

# %%
df['new_col']=df['x']*df['y']

# %%
df
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df['new_col1']=df['x']*df['y']*df['z']

# %%
df
# Out:
#           w         x         y         z         v   new_col  new_col1
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120 -0.050509
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236  0.024846
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025 -0.708859
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876  0.082554
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449 -0.079109

# %%
df.drop('new_col1',axis=1)
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df
# Out:
#           w         x         y         z         v   new_col  new_col1
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120 -0.050509
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236  0.024846
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025 -0.708859
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876  0.082554
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449 -0.079109

# %%
df.drop('new_col1',axis=1,inplace=True)

# %%
df
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df.drop('d')
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df.drop(['d','e'])
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
np.where(titanic_train['Age'].isnull()==True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train.drop(np.where(titanic_train['Age'].isnull()==True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-0713ac5a8c39> in <module>
# ----> 1 titanic_train.drop(np.where(titanic_train['Age'].isnull()==True))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
ind=np.where(titanic_train['Age'].isnull()==True)

# %%
titanic_train.drop(ind[0])

# %%
df

# %%
df.iloc[[0,1],[5,4]]

# %%
df.loc[['a','b'],['x','y']]

# %%
df.iloc[0:1:3]
# Out:
#           w         x         y         z         v  new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.12312

# %%
df>0
# Out:
#        w      x      y      z      v  new_col
# a  False  False   True   True  False    False
# b   True   True  False  False  False    False
# c  False  False  False  False   True     True
# d  False  False   True  False  False    False
# e  False   True   True  False  False     True

# %%
df[df>0]
# Out:
#          w         x         y         z         v   new_col
# a      NaN       NaN  0.824062  0.410243       NaN       NaN
# b  1.24821  0.470598       NaN       NaN       NaN       NaN
# c      NaN       NaN       NaN       NaN  1.085628  0.943025
# d      NaN       NaN  0.939009       NaN       NaN       NaN
# e      NaN  0.045144  0.895999       NaN       NaN  0.040449

# %%
df
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df[df['z']<0]
# Out:
#           w         x         y         z         v   new_col
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df[(df['x']<0) & (df['v']<0)]
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876

# %%
df
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df.reset_index()
# Out:
#   index         w         x         y         z         v   new_col
# 0     a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# 1     b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# 2     c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# 3     d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# 4     e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df
# Out:
#           w         x         y         z         v   new_col
# a -0.074784 -0.149406  0.824062  0.410243 -0.560795 -0.123120
# b  1.248210  0.470598 -0.191748 -0.275342 -0.035742 -0.090236
# c -0.080530 -1.893274 -0.498092 -0.751686  1.085628  0.943025
# d -1.391370 -1.669714  0.939009 -0.052653 -0.479798 -1.567876
# e -1.378213  0.045144  0.895999 -1.955758 -2.215619  0.040449

# %%
df.set_index('z')
# Out:
#                   w         x         y         v   new_col
# z
#  0.410243 -0.074784 -0.149406  0.824062 -0.560795 -0.123120
# -0.275342  1.248210  0.470598 -0.191748 -0.035742 -0.090236
# -0.751686 -0.080530 -1.893274 -0.498092  1.085628  0.943025
# -0.052653 -1.391370 -1.669714  0.939009 -0.479798 -1.567876
# -1.955758 -1.378213  0.045144  0.895999 -2.215619  0.040449

# %%
df=pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]})
df['States']="CA DA DF".split()
df.set_index('States',inplace=True)
print(df)
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# DA      2.0  NaN  2
# DF      NaN  NaN  3
