# %%
import pandas as pd

# %%
pd.read_csv("D:/project/ohana-api-master/data/sample-csv/locations.csv")
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pwd()
# Out:
# 'C:\\Users\\Admin'

# %%
df=pd.read_csv("D:/project/ohana-api-master/data/sample-csv/locations.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
df.head()
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
# 2   3                1                                           NaN
# 3   4                1                                    wheelchair
# 4   5                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
#
# ...

# %%
df.head(2)
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
#
#                                        languages   latitude   longitude  \
# 0                               Spanish, Tagalog  37.477227 -122.213221
# 1  Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
#
#                                name  \
# 0   Fair Oaks Adult Activity Center
# 1  Second Career Employment Program
#
#                                           short_desc  \
# 0  A multipurpose senior citizens' center serving...
# ...

# %%
df.tail()
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 17  18                5                cd, restroom, wheelchair          NaN
# 18  19                5              elevator, ramp, wheelchair          NaN
# 19  20                6                                     NaN          NaN
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# 17            NaN  Provides free medical care to those in need. O...
# 18            NaN  Provides free medical and dental care to those...
# 19            NaN                                           no phone
# 20            NaN                              This is a description
# 21  The Test Spot  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                email                                        languages  \
# ...

# %%
df.tail(3)
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 19  20                6                                     NaN          NaN
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# 19            NaN                                           no phone
# 20            NaN                              This is a description
# 21  The Test Spot  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                email                                        languages  \
# 19               NaN                                              NaN
# 20               NaN                                              NaN
# 21  info@example.org  Cantonese, Russian, Spanish, Tagalog, Taiwanese
#
#      latitude   longitude                    name  \
# ...

# %%
pd.read_csv('D:/project/ohana-api-master/data/sample-csv/locations.csv',header=None)
# Out:
#     0                1                                                  2   \
# 0   id  organization_id                                      accessibility
# 1    1                1       disabled_parking, ramp, restroom, wheelchair
# 2    2                1                                         wheelchair
# 3    3                1                                                NaN
# 4    4                1                                         wheelchair
# 5    5                1                                         wheelchair
# 6    6                2                       disabled_parking, wheelchair
# 7    7                2       ramp, restroom, disabled_parking, wheelchair
# 8    8                2                                                NaN
# 9    9                3                         ramp, restroom, wheelchair
# 10  10                3  elevator, tape_braille, ramp, restroom, disabl...
# ...

# %%
pd.read_csv('D:/project/ohana-api-master/data/sample-csv/locations.csv',header=None,names=['a','b','c','a1','b1','c1','2a','b2','c2','a3','b3','c3','a4','b4','c4'])
# Out:
#      a                b                                                  c  \
# 0   id  organization_id                                      accessibility
# 1    1                1       disabled_parking, ramp, restroom, wheelchair
# 2    2                1                                         wheelchair
# 3    3                1                                                NaN
# 4    4                1                                         wheelchair
# 5    5                1                                         wheelchair
# 6    6                2                       disabled_parking, wheelchair
# 7    7                2       ramp, restroom, disabled_parking, wheelchair
# 8    8                2                                                NaN
# 9    9                3                         ramp, restroom, wheelchair
# 10  10                3  elevator, tape_braille, ramp, restroom, disabl...
# ...

# %%
pd.read_csv('D:/project/ohana-api-master/data/sample-csv/locations.csv',names=['a','b','c','a1','b1','c1','2a','b2','c2','a3','b3','c3','a4','b4','c4'])
# Out:
#      a                b                                                  c  \
# 0   id  organization_id                                      accessibility
# 1    1                1       disabled_parking, ramp, restroom, wheelchair
# 2    2                1                                         wheelchair
# 3    3                1                                                NaN
# 4    4                1                                         wheelchair
# 5    5                1                                         wheelchair
# 6    6                2                       disabled_parking, wheelchair
# 7    7                2       ramp, restroom, disabled_parking, wheelchair
# 8    8                2                                                NaN
# 9    9                3                         ramp, restroom, wheelchair
# 10  10                3  elevator, tape_braille, ramp, restroom, disabl...
# ...

# %%
pd.read_csv('D:/project/ohana-api-master/data/sample-csv/locations.csv',skiprows=[2,5,6,8,22,20])
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    3                1                                                NaN
# 2    4                1                                         wheelchair
# 3    7                2       ramp, restroom, disabled_parking, wheelchair
# 4    9                3                         ramp, restroom, wheelchair
# 5   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 6   11                3                                               ramp
# 7   12                3         disabled_parking, elevator, ramp, restroom
# 8   13                3                                                NaN
# 9   14                4                                         wheelchair
# 10  15                4                                         wheelchair
# ...

# %%
pd.read_csv('D:/project/ohana-api-master/data/sample-csv/locations.csv',na_values=['wheelchair'])
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                                NaN
# 2    3                1                                                NaN
# 3    4                1                                                NaN
# 4    5                1                                                NaN
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv('D:/project/ohana-api-master/data/sample-csv/locations.csv',na_values=['Null'])
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_excel('D:/project/java-read-write-excel-file-using-apache-poi-master/java-read-write-excel-file-using-apache-poi-master/sample-xlsx-file.xlsx')
# Out:
#            Name               Email Date Of Birth   Salary  \
# 0  Rajeev Singh  rajeev@example.com    1992-07-21  1500000
# 1      John Doe    john@example.com    1965-01-13  1300000
# 2  Jack Sparrow    jack@example.com    1986-12-19  1000000
# 3   Steven Cook  steven@example.com    1994-05-04  1200000
#
#              Department
# 0  Software Engineering
# 1                 Sales
# 2                    HR
# 3             Marketing

# %%
pd.read_excel('D:/project/java-read-write-excel-file-using-apache-poi-master/java-read-write-excel-file-using-apache-poi-master/sample-xlsx-file.xlsx',sheet_name='Department')
# Out:
#                    Name   Budget
# 0  Software Engineering  5000000
# 1                    HR  2000000
# 2                 Sales  4000000
# 3             Marketing  3000000

# %%
a=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2021_leaders.html')

# %%
a
# Out:
# [       0                            1     2
#  0    1.0          Stephen Curry • GSW  2015
#  1    2.0         Damian Lillard • POR  1928
#  2    3.0           Nikola Jokić • DEN  1898
#  3    4.0           Bradley Beal • WAS  1878
#  4    5.0            Luka Dončić • DAL  1830
#  5    6.0  Giannis Antetokounmpo • MIL  1717
#  6    7.0           Devin Booker • PHO  1712
#  7    NaN          Julius Randle • NYK  1712
#  8    9.0           Jayson Tatum • BOS  1692
#  9   10.0        Zion Williamson • NOP  1647
#  10  11.0         Nikola Vučević • TOT  1639
#  11  12.0             Trae Young • ATL  1594
#  12  13.0            Zach LaVine • CHI  1591
#  13  14.0           De'Aaron Fox • SAC  1461
#  14  15.0          Collin Sexton • CLE  1460
#  15  16.0            Joel Embiid • PHI  1451
#  16   NaN           Kyrie Irving • BRK  1451
#  17  18.0         Brandon Ingram • NOP  1450
#  18  19.0      Russell Westbrook • WAS  1445
#  19  20.0           Jaylen Brown • BOS  1430,
# ...

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 50

# %%
a[0]
# Out:
#        0                            1     2
# 0    1.0          Stephen Curry • GSW  2015
# 1    2.0         Damian Lillard • POR  1928
# 2    3.0           Nikola Jokić • DEN  1898
# 3    4.0           Bradley Beal • WAS  1878
# 4    5.0            Luka Dončić • DAL  1830
# 5    6.0  Giannis Antetokounmpo • MIL  1717
# 6    7.0           Devin Booker • PHO  1712
# 7    NaN          Julius Randle • NYK  1712
# 8    9.0           Jayson Tatum • BOS  1692
# 9   10.0        Zion Williamson • NOP  1647
# 10  11.0         Nikola Vučević • TOT  1639
# 11  12.0             Trae Young • ATL  1594
# 12  13.0            Zach LaVine • CHI  1591
# 13  14.0           De'Aaron Fox • SAC  1461
# 14  15.0          Collin Sexton • CLE  1460
# 15  16.0            Joel Embiid • PHI  1451
# 16   NaN           Kyrie Irving • BRK  1451
# 17  18.0         Brandon Ingram • NOP  1450
# 18  19.0      Russell Westbrook • WAS  1445
# 19  20.0           Jaylen Brown • BOS  1430

# %%
a[1]
# Out:
#        0                            1     2
# 0    1.0          Stephen Curry • GSW  32.0
# 1    2.0           Bradley Beal • WAS  31.3
# 2    3.0         Damian Lillard • POR  28.8
# 3    4.0            Joel Embiid • PHI  28.5
# 4    5.0  Giannis Antetokounmpo • MIL  28.1
# 5    6.0            Luka Dončić • DAL  27.7
# 6    7.0            Zach LaVine • CHI  27.4
# 7    8.0        Zion Williamson • NOP  27.0
# 8    9.0           Kyrie Irving • BRK  26.9
# 9   10.0           Jayson Tatum • BOS  26.4
# 10  11.0       Donovan Mitchell • UTA  26.4
# 11  12.0           Nikola Jokić • DEN  26.4
# 12  13.0           Devin Booker • PHO  25.6
# 13  14.0             Trae Young • ATL  25.3
# 14  15.0           De'Aaron Fox • SAC  25.2
# 15  16.0          Kawhi Leonard • LAC  24.8
# 16  17.0           Jaylen Brown • BOS  24.7
# 17  18.0          Collin Sexton • CLE  24.3
# 18  19.0          Julius Randle • NYK  24.1
# 19  20.0         Brandon Ingram • NOP  23.8

# %%
d=pd.read_csv('D:/project/datasets-master/datasets-master/titanic.csv')

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
d.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
d.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
d.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(d[['Survived']])
# Out:
# pandas.core.frame.DataFrame

# %%
d[['Survived','Parch']]
# Out:
#      Survived  Parch
# 0           0      0
# 1           1      0
# 2           1      0
# 3           1      0
# 4           0      0
# ..        ...    ...
# 886         0      0
# 887         1      0
# 888         0      2
# 889         1      0
# 890         0      0
#
# [891 rows x 2 columns]

# %%
type(d['Survived'])
# Out:
# pandas.core.series.Series
